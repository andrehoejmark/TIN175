# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("..\\..\\data\\merged.csv", sep=';')
df = df.set_index(pd.DatetimeIndex(df['Datum'] + ' ' + df['Tid (UTC)']))
df = df.drop('Datum', 1)
df = df.drop('Tid (UTC)', 1)
df = df.replace('-', np.nan)
df=df.astype(float)
df.head(50)
# Out:
# C:\PYTHON\RNN\TIN175\venv\lib\site-packages\IPython\core\interactiveshell.py:3044: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      barkakra temperature  barkakra wind  barkakra wind #2  \
# 1939-01-01 07:00:00                   NaN            NaN               NaN
# 1939-01-01 13:00:00                   NaN            NaN               NaN
# 1939-01-01 18:00:00                   NaN            NaN               NaN
# 1939-01-02 07:00:00                   NaN            NaN               NaN
# 1939-01-02 13:00:00                   NaN            NaN               NaN
# 1939-01-02 18:00:00                   NaN            NaN               NaN
# 1939-01-03 07:00:00                   NaN            NaN               NaN
# 1939-01-03 13:00:00                   NaN            NaN               NaN
# ...

# %% [markdown]
# # Gothenburg

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
df['gothenburg temperature'].plot(ax=axes[0,0], title='temp')
df['gothenburg pressure'].plot(ax=axes[0,1], title='pressure')
df['gothenburg wind'].plot(ax=axes[1,0], title='wind direction')
df['gothenburg wind #2'].plot(ax=axes[1,1], title='wind speed', figsize=(17, 17))

# %% [markdown]
# # Baråkra

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['barkakra temperature'].plot(ax=axes[0,0], title='temp')
df['barkakra pressure'].plot(ax=axes[0,1], title='prssure')
df['barkakra wind'].plot(ax=axes[1,0], title='wind direction')
df['barkakra wind #2'].plot(ax=axes[1,1], title='wind speed', figsize=(17, 17))

# %% [markdown]
# # Jönköping airport

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['jonkoping temperature'].plot(ax=axes[0,0], title='temp')
df['jonkoping pressure'].plot(ax=axes[0,1], title='pressure')
df['jonkoping wind'].plot(ax=axes[1,0], title='wind direction')
df['jonkoping wind #2'].plot(ax=axes[1,1], title='wind speed', figsize=(17, 17))

# %% [markdown]
# # Väderöarna

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['vaderoarna temperature'].plot(ax=axes[0,0], title='temp')
df['vaderoarna pressure'].plot(ax=axes[0,1], title='pressure')
df['vaderoarna wind'].plot(ax=axes[1,0], title='wind direction')
df['vaderoarna wind #2'].plot(ax=axes[1,1], title='wind speed', figsize=(17, 17))

# %% [markdown]
# # Vinga A

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['vinga temperature'].plot(ax=axes[0,0], title='temp')
df['vinga pressure'].plot(ax=axes[0,1], title='pressure')
df['vinga wind'].plot(ax=axes[1,0], title='wind direction')
df['vinga wind #2'].plot(ax=axes[1,1], title='wind speed', figsize=(17, 17))
