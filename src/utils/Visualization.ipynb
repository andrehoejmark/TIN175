# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("..\\..\\data\\merged.csv", sep=';')
df = df.set_index(pd.DatetimeIndex(df['Datum'] + ' ' + df['Tid (UTC)']))
df = df.drop('Datum', 1)
df = df.drop('Tid (UTC)', 1)
df.head()
# Out:
#                      barkakra temperature  barkakra wind  barkakra wind #2  \
# 2018-10-28 03:00:00                   0.6             20               3.0
# 2018-10-28 04:00:00                   0.6             10               2.0
# 2018-10-28 05:00:00                   0.8             30               4.0
# 2018-10-28 06:00:00                   0.9            100               1.0
# 2018-10-28 07:00:00                   1.2             50               3.0
#
#                      barkakra pressure  gothenburg temperature  \
# 2018-10-28 03:00:00             1018.3                     0.2
# 2018-10-28 04:00:00             1019.0                     0.7
# 2018-10-28 05:00:00             1019.5                     0.7
# 2018-10-28 06:00:00             1020.3                     0.1
# 2018-10-28 07:00:00             1021.0                    -0.5
#
#                      gothenburg wind  gothenburg wind #2  gothenburg pressure  \
# ...

# %% [markdown]
# # Gothenburg

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['gothenburg temperature'].plot(ax=axes[0,0], title='temp')
df['gothenburg pressure'].plot(ax=axes[0,1], title='temp')
df['gothenburg wind'].plot(ax=axes[1,0], title='temp')
df['gothenburg wind #2'].plot(ax=axes[1,1], title='temp', figsize=(17, 17))
# Out:
# "\nplt.plot(df['gothenburg temperature'])\nplt.xlabel('time')\nplt.ylabel('temp')\n\nplt.subplot(2, 2, 2)\nplt.plot(df['gothenburg pressure'])\nplt.xlabel('time')\nplt.ylabel('pressure')\n\nplt.subplot(2, 2, 3)\nplt.plot(df['gothenburg wind'])\nplt.xlabel('time')\nplt.ylabel('wind_direction')\n\nplt.subplot(2, 2, 4)\nplt.plot(df['gothenburg wind #2'])\nplt.xlabel('time')\nplt.ylabel('wind_speed')\n"

# %% [markdown]
# # Baråkra

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['barkakra temperature'].plot(ax=axes[0,0], title='temp')
df['barkakra pressure'].plot(ax=axes[0,1], title='temp')
df['barkakra wind'].plot(ax=axes[1,0], title='temp')
df['barkakra wind #2'].plot(ax=axes[1,1], title='temp', figsize=(17, 17))

# %% [markdown]
# # Jönköping airport

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['jonkoping temperature'].plot(ax=axes[0,0], title='temp')
df['jonkoping pressure'].plot(ax=axes[0,1], title='temp')
df['jonkoping wind'].plot(ax=axes[1,0], title='temp')
df['jonkoping wind #2'].plot(ax=axes[1,1], title='temp', figsize=(17, 17))

# %% [markdown]
# # Väderöarna

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['vaderoarna temperature'].plot(ax=axes[0,0], title='temp')
df['vaderoarna pressure'].plot(ax=axes[0,1], title='temp')
df['vaderoarna wind'].plot(ax=axes[1,0], title='temp')
df['vaderoarna wind #2'].plot(ax=axes[1,1], title='temp', figsize=(17, 17))

# %% [markdown]
# # Vinga A

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

df['vinga temperature'].plot(ax=axes[0,0], title='temp')
df['vinga pressure'].plot(ax=axes[0,1], title='temp')
df['vinga wind'].plot(ax=axes[1,0], title='temp')
df['vinga wind #2'].plot(ax=axes[1,1], title='temp', figsize=(17, 17))
